# %% [markdown]
# #Statistics Advance Part 1

# %% [markdown]
# 1. What is a random variable in probability theory?
# ANS: It is a set of possible value from a random experiment. A random variable, value is unknown. A function that assign values to each of experiment outcomes
# It is a variable whose value is subject to randomness or uncertainty.

# %% [markdown]
# 2. What are the types of random variables?
# ANS: Random variables are of the two main types:
# **Discrete Random Variables**:
# - A discrete random Variable can take on a finite or countably infinite number of distinct value.
# - e.g:  Rolling a dice, Tossing a coin
# - The probability distribution for discrete random variable is given by a probability mass function , which assign probabilities to each possible outcome.
#
# **Continuous Random Variable**:
# - A continuous random variable can take any value within a certain range or interval, often corresponding to real numbers.
# - e.g: Height, Temperature
# - The probability distribution for continuous random variable is given by a probability density function, which describe the likelihood oof the variable falling within a particular range rather than taking specific values.

# %% [markdown]
# 3. What is the difference between discrete and continuous distributions?
# ANS: **Discrete Distributions:**
# - A discrete distributions applies to a discrete random variable, which takes on a finite or countably infinite set of values value.
# - e.g: Rolling a dice, Tossing a coin,
# - It represented as Probability Mass Function, which gives the Probability of each individual outcome
# - Probabilities are assigned to specific values, and the sum of all Probabilities must equal 1.
#
# **Continuous Distributions:**
# - A continuous distributions applies to a continuous random variable , which can take any value within a certain range.
# - e.g: Height, Temperature
# - It represents as probability density function, where the probability of the random variable falling within an iterval [a,b] is given by the area under the curve of the probability density function from a and b.
# - Probabilities are assigned over intervals rather than specific values, since the probability of any single exact value is Zero.

# %% [markdown]
# 4. What are probability distribution functions (PDF)?
# ANS: A probability distribution functions describes how probabilities are assigned to different values of a random variable. There are different type of distribution functions depending on whether the variable is discrete or continuous.

# %% [markdown]
# 5.  How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# ANS: The cumulative distribution functions (CDF) and probability distribution functions (PDF) both describe probability distribution.
# **PDF:**
# - PDF gives the likelihood of a random variable taking a specific  value or falling within a small interval.
# - PDF gives the bell curve equation.
# - It can be positive for discrete , zero for continuous.
# - The CDF is the integral of the PDF
#
# **CDF**
# - CDF is summation of all probabilities possible up to a given point.
# - CDF gives the area under the curve from - ∞ to x, which can be found using statstical tables or integration.
# - It always increases from 0 to 1.
# - The PDF is the deivative of the CDF.

# %% [markdown]
# 6. What is a discrete uniform distribution?
# ANS: The discrete uniform distribution, the outcomes are discrete and have the same probability.
# e.g: Rolling a dice, Tossing a coin

# %% [markdown]
# 7.  What are the key properties of a Bernoulli distribution?
# ANS: A discrete probability distribution of a random variable which takes only two possible outcomes, typically labelled as success( coded as 1) and failure (coded as 0) which a fixed probability of success and failure i.e sum of probability is 1/.
# - To model any experiment with only two possible outcomes.

# %% [markdown]
# 8.  What is the binomial distribution, and how is it used in probability?
# ANS: The binomial distribution is the 'n' bernoulli trial.
# - Binomial distribution the probability of getting a certain number of success in a fixed number of independent trails, where each trial has only two possible outcomes i.e success (p) or failure(1-p).
# - The binomial distribution is widely used in real world applications including Quality control, sport analysis

# %% [markdown]
# 9. What is the Poisson distribution and where is it applied?
# ANS: The Poisson distribution is a discrete probability distribution that describe the number of events that occur within a fixed interval of time or space given a known average rate of occurrence.
# - Number of events occurring in a fixed time interval.
# - The Poisson distribution is used when events occurs randomly over time or space at a known average rate.
# - e.g: Number of people visiting temple or airport.

# %% [markdown]
# 10. What is a continuous uniform distribution?
# ANS: A continuous uniform distribution is a distribution that has infinite number of value defined in a specific range or bound.
# - A random variable is continuous.
# - It is also called as rectangular distribution.
# - e.g: OTP, Temperature variation in a day.

# %% [markdown]
# 11. What are the characteristics of a normal distribution?
# ANS: The normal distribution is called as Gaussian distribution.
# - It is continuous probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence that data far from the mean.
# -It is also called as bell-shaped distribution.
# - Most of the real world data follows a normal distribution.
# - Characteristics: It is symmetrical about mean.
# mean = median = mode. Skewness = 0
# - It is used empirical rule i.e 68%-95%-99.7%

# %% [markdown]
# 12. What is the standard normal distribution, and why is it important?
# ANS: The standard normal distribution is continuous probability distribution.
# - Special case of normal distribution because mean can by anything.
# - In this mean and median is always fixed.
# - The standard normal distribution is a special case of the normal distribution where the mean is 0 and standard distribution is 1.
# - We used standard normal distribution because it simplifies calculations and comparisons.
# - Instead of working with different normal distribution with varying means and standard distribution we can standardize any normal distribution into standard normal distribution using Z-Score.

# %% [markdown]
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# ANS: The Central Limit Theorem that if you have population with mean and standard distribution and take sufficiently large number of random samples from the population with replacement than the distribution of sample means will be approximately normally distributed.
# - CLT allows us to use normal distribution based methods, such as confidence intervals and hypothesis testing, even if the underlying population distribution is not normal.
# - When taking the mean of a large number of data points , the influence of outliers or extreme values is reduced. The CLT ensures that sample means are stable and less sensitive to unusual data points.

# %% [markdown]
# 14. How does the Central Limit Theorem relate to the normal distribution?
# ANS: The Central Limit Theorem and the normal distribution are connected because the CLT explains why sample means tend to follow a normal distribution, even if the population data itself is not normal. The CLT as the sample size increases, the distribution of sample means tends to follow a normal distribution, no matter the shape of the population distribution. The normal distribution is important in statistics - it becomes the default model for sample means as the sample size grows, allowing us to apply powerful statistical tools to analyze data.

# %% [markdown]
# 15. What is the application of Z statistics in hypothesis testing?
# ANS: In hypothesis testing, Z statistics are used to determine whether to reject a null hypothesis about a population parameter. They help access whether the observed data is consistent with the null hypothesis or if it falls into the critical region, suggesting that the null hypothesis should be rejected.
# - Z- statistics are commonly used to test whether the sample mean is significantly different from a known or hypothesized population mean.
# - Z tests are especially useful when the sample size is large, and the population standard deviations is known.

# %% [markdown]
# 16. How do you calculate a Z-score, and what does it represent?
# ANS: A Z-score is a measure that describes a value's position in terms of its distance from the mean of a dataset, expressed in terms of standard deviations.
# - A Z-score tells you how many standard deviations a particular data point is from the mean of a dataset.
# - Calculate by using formula
#  Z =  X - μ / Standard deviation
#  First find the mean and then standard deviation and calculate the Z-Score
# - e.g: Score= 65, 70, 75, 80, 85
# mean= 75
# standard deviation= 7.91
# Z= 0.63
# It represent:
# - A Z-score of 0 means the data point is exactly at the mean.
# - A positive Z-score means the data point is above the mean.
# - A negative Z-score means the data point is below the mean.
# - The magnitude of the Z-score indicates how many standard deviations the data point is away from the mean.

# %% [markdown]
# 17. What are point estimates and interval estimates in statistics?
# ANS: Point estimates: A Point estimate is a single value that is used to estimate the true value of a population parameter.
#
# Interval estimates: Range of values used to estimate the unknown population parameter.

# %% [markdown]
# 18. What is the significance of confidence intervals in statistical analysis?
# ANS: Confidence intervals are a fundamental concept in statistical analysis, providing a way to express the uncertainty around a sample estimate of a population parameter. They offer a range of plausible values for the true parameter, helping researchers, analysts and decision makers make more informed conclusions. This not only helps quantify uncertainty but also aids in decision- making, hypothesis testing and making reliable conclusions from sample data.

# %% [markdown]
# 19. What is the relationship between a Z-score and a confidence interval?
# ANS:  A Z-score and a confidence interval are related in that the Z-score helps define the margin of error around a sample statistic, and ultimately, the confidence interval itself.
# - The Z-score is used to calculate how far we extend from the sample mean to create the confidence interval.
# - Z-scores help define the range of values for the confidence interval by determining how many standard deviations from the sample mean the interval should extend based on the desired confidence level.
# - Together, they allow statisticians and analyst to quantify uncertainty and assess the reliability of their estimates, making decisions more data driven and informed.

# %% [markdown]
# 20. How are Z-scores used to compare different distributions?
# ANS: Z-scores are a valuable tool for comparing data points from different distributions, even when those distributions have different means and standard deviations.
# - Z-scores convert raw data into standardized values, making it easier to compare values from different distributions, regardless of their means or standard deviations.
# - They allow you to compare the relative position of a value within each distribution, and by using Z-scores, you can assess how extreme or typical the values are in their respective contexts.
# - Z-scores allow you to compare how extreme or typical a value is relative to its own distribution and in comparison to other distribution.

# %% [markdown]
# 21. What are the assumptions for applying the Central Limit Theorem?
# ANS: The CLT is a fundamental concept in statistics that describes how the sampling distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the shape of the population distribution.
# - The observations within each sample must be independent of one another. This means that one data point should not influence another.
# - Number of sample should be large.
# - Sample size should be greater than 30.
# - The population must have a finite variance.
# - If the population is non- normal, a larger sample size may be required for normality.

# %% [markdown]
# 22. What is the concept of expected value in a probability distribution?
# ANS: In the long run average value of repetition of experiment it represent.
# - Long term average value of a random variable is expected value.
# - The expected value of a probability distribution is a measure of the central tendency or the average outcome of a random variable, considering the probabilities of all possible outcome.

# %% [markdown]
# 23. How does a probability distribution relate to the expected outcome of a random variable?
# ANS: A probability distribution provides the structure for understanding the behavior of a random variable, including all possible values the variable can take and the likelihood of each of those values occurring. The expected value of a probability distribution is a measure of the central tendency or the average outcome of a random variable, considering the probabilities of all possible outcome.
# - The probability distribution of a random variable gives a complete description of the variables behavior, including the set of all possible values and their corresponding probabilities.
# - The expected value provides insight into what you would expect on average if the random experiment were repeated many times.

# %% [markdown]
# #Practical

# %% [markdown]
# 1. Write a Python program to generate a random variable and display its value.

# %%
import random
random_variable = random.randint(1, 10)
print("Generated random variable value:", random_variable)
# Out:
# Generated random variable value: 7

# %% [markdown]
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt
low = 1
high = 6
samples = np.random.randint(low, high + 1, size=1000)
unique, counts= np.unique(samples, return_counts=True)
pmf = counts / len(samples)
plt.bar(unique, pmf)
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Discrete Uniform Distribution PMF')
plt.show()

# %% [markdown]
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def bernoulli_pdf(p, x):
    if x not in [0, 1]:
        raise ValueError("Input must be 0 or 1")

    if not (0 <= p <= 1):
        raise ValueError("Probability p must be between 0 and 1")

    if x == 1:
        return p
    else:
        return 1- p

print(bernoulli_pmf(1, 0.7))
print(bernoulli_pmf(0, 0.7))
# Out:
# 0.7
# 0.30000000000000004

# %% [markdown]
# 4.  Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10
p = 0.5
size = 1000
data = np.random.binomial(n, p, size)

bins = np.arange(n + 2) - 0.5
plt.hist(data, bins=bins, align='left', density=True, alpha=0.5, color='b')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Binomial Distribution')
plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

lambda_ = 5
size = 1000

data = np.random.poisson(lambda_, size)
plt.figure(figsize=(8,5))
sns.histplot(data, bins=range(0, max(data)+1),kde=False,  color='red', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Poisson Distribution')
plt.show()

# %% [markdown]
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution>

# %%
import numpy as np
import matplotlib.pyplot as plt

low = 1
high = 6
size = 1000

data= np.random.randint(low, high + 1, size)
unique, counts = np.unique(data, return_counts=True)
pmf = counts / len(data)
cdf = np.cumsum(pmf)
plt.bar(unique, cdf)
plt.xlabel('Value')
plt.ylabel('CDF')
plt.title('Discrete Uniform Distribution CDF')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

a, b = 1, 10

x = np.arange(a, b + 1)

cdf_values = stats.randint.cdf(x, a, b + 1)

plt.figure(figsize=(8, 5))
plt.step(x, cdf_values, where="mid", color="blue", label="CDF", linewidth=2)

plt.xlabel("x (Values)")
plt.ylabel("Cumulative Probability")
plt.title("CDF of a Discrete Uniform Distribution")
plt.xticks(x)
plt.yticks(np.linspace(0, 1, b - a + 2))
plt.grid(axis='y', linestyle="--", alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# 7. Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

a, b = 2, 10
size = 1000

data = np.random.uniform(a, b, size)

plt.figure(figsize=(8,5))
sns.histplot(data, bins=20, kde=False, color='blue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Continuous Uniform Distribution')
plt.show()

# %% [markdown]
# 8.  Simulate data from a normal distribution and plot its histogram

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

mean = 0
std_dev = 1
size = 1000

data = np.random.normal(mean, std_dev, size)

plt.figure(figsize=(8,5))
plt.hist(data, bins=30, density=True, alpha=0.6, color='blue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Normal Distribution')
plt.grid(axis="y", linestyle= "--", alpha= 0.7 )
plt.show()

# %% [markdown]
# 9. Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def calculate_z_score(data):
    mean = np.mean(data)
    std_dev = np.std(data)
    z_scores = (data - mean) / std_dev
    return z_scores

def plot_z_scores(z_scores):
    plt.figure(figsize=(8, 5))
    sns.histplot(z_scores, bins=30, kde=True, color='blue', edgecolor='black')
    plt.xlabel('Z-Score')
    plt.ylabel('Frequency')
    plt.title('Z-Score Distribution')
    plt.legend()
    plt.grid(axis="y", linestyle= "--", alpha= 0.7)
    plt.show()


np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)
z_scores = calculate_z_score(data)
plot_z_scores(z_scores)
# Out:
# <ipython-input-24-fe19b08e31dd>:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

population_size = 1000
population = np.random.normal(scale=2, size=population_size)

def sample_mean(population, sample_size, num_samples=1000):
    mean_samples = [np.mean(np.random.choice(population, size=sample_size, replace=True)) for _ in range(num_samples)]
    return np.array(mean_samples)

sample_size = [5, 30, 100]
plt.figure(figsize=(12,5))

for i, size in enumerate(sample_size, 1):
    sample_means_data = sample_mean(population, size)

    plt.subplot(1, 3, i)
    sns.histplot(sample_means_data, bins=30, kde=True, color='blue', edgecolor='black')
    plt.xlabel("Sample Mean")
    plt.ylabel("Density")
    plt.title(f"Sample Size = {size}")
    plt.axvline(np.mean(population), color='red', linestyle='dashed', label="Population Mean")
    plt.legend()

plt.suptitle("Central Limit Theorem for Non-Normal Distribution", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# 15. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

population_size = 100000
mu, sigma = 0, 1
population = np.random.normal(mu, sigma, population_size)

def sample_mean(population, sample_size, num_samples=1000):
    mean_samples = [np.mean(np.random.choice(population, size=sample_size, replace=True)) for _ in range(num_samples)]
    return np.array(mean_samples)

sample_size = [5, 30, 100]
plt.figure(figsize=(12,5))

for i, size in enumerate(sample_size, 1):
    sample_means_data = sample_mean(population, size)

    plt.subplot(1, 3, i)
    sns.histplot(sample_means_data, bins=30, kde=True, color='blue', edgecolor='black', stat='density')
    plt.title(f"sample size = {size}")
    plt.xlabel("Sample Mean")
    plt.ylabel("Density")
    plt.axvline(np.mean(population), color='red', linestyle='dashed', label="Population Mean")
    plt.legend()

plt.suptitle("Central Limit Theorem: Sample Mean Distributions", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# 16. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy. stats import norm

def plot_standard_normal_distribution():
    mean = 0
    std_dev = 1
    x = np.linspace(-4, 4, 100)
    y = norm.pdf(x, mean, std_dev)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, color='blue', linewidth = 2, label="Standard Normal Distribution")
    plt.fill_between(x, y, color= 'blue', alpha=0.5)
    plt.title("Standard Normal Distribution")
    plt.xlabel("x", fontsize= 12)
    plt.ylabel("Probability Density", fontsize= 12)
    plt.axvline(0, color= 'red', linestyle= 'dashed', label= "Mean (x=0)")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_standard_normal_distribution()

# %% [markdown]
# 17. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy. stats import binom

def generate_binomial_distribution(n, p, size = 1000):
    random_variables = np.random.binomial(n, p, size)
    unique, counts = np.unique(random_variables, return_counts=True)
    probabilities = binom.pmf(unique, n, p)

    plt.figure(figsize=(8,5))
    plt.hist(random_variables, bins= range(n+1), density=True, alpha=0.6, color='blue', edgecolor='black')
    plt.plot(unique, probabilities, 'o', color='red', label='Binomial Distribution')
    plt.xlabel('Number of success (k)', fontsize=12)
    plt.ylabel('Probability', fontsize=12)
    plt.title('Binomial Distribution', fontsize=14)
    plt.xticks(range(n+1))
    plt.legend()
    plt.grid(True)
    plt.show()

    for k, prob in zip(unique, probabilities):
        print(f"p(X= {k}) = {prob:.4f}")

n = 10
p = 0.5
size = 1000

generate_binomial_distribution(n, p, size)
# Out:
# p(X= 0) = 0.0010
# p(X= 1) = 0.0098
# p(X= 2) = 0.0439
# p(X= 3) = 0.1172
# p(X= 4) = 0.2051
# p(X= 5) = 0.2461
# p(X= 6) = 0.2051
# p(X= 7) = 0.1172
# p(X= 8) = 0.0439
# p(X= 9) = 0.0098
# p(X= 10) = 0.0010

# %% [markdown]
# 18. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy. stats import norm

def calculate_z_score(data_point, mean, std_dev):
    z_score = (data_point - mean) / std_dev
    prob = norm.cdf(z_score)
    print(f"Z-score for the data point {z_score:.4f}:, Probability: {prob:.4f} ")

    x = np.linspace(-4, 4, 100)
    plt.plot(x, norm.pdf(x), label='Standard Normal')
    plt.axvline(z_score, color='red', linestyle='dashed', label=f'Z-score = {z_score:.2f}')
    plt.legend()
    plt.title("Standard Normal Distribution")
    plt.grid(True)
    plt.show()

calculate_z_score(120, 100, 15)
# Out:
# Z-score for the data point 1.3333:, Probability: 0.9088

# %% [markdown]
# 19. Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy. stats import norm

def z_test(sample_data, population_mean, population_std, alpha=0.05):
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)
    z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    z_critical = norm.ppf(1- alpha/2)

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-statistic: {z_stat:.2f}")
    print(f"Critical Z-value: {z_critical:.2f}")

    if abs(z_stat) > z_critical:
        print("Reject the null hypothesis")
    else:
        print("Fail to reject the null hypothesis")

sample_data = np.array([85, 88, 92, 91, 87, 90, 85, 86, 89, 91])

population_mean = 90
population_std = 5

z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 88.40
# Z-statistic: -1.01
# Critical Z-value: 1.96
# Fail to reject the null hypothesis

# %% [markdown]
# 20. Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
from scipy. stats import norm

def confidence_interval(data, std_dev, confidence_level=0.95):
    sample_mean = np.mean(data)
    sample_size = len(data)
    z_critical = norm.ppf(1 - (1 - confidence_level) / 2)
    margin_of_error = z_critical * (std_dev / np.sqrt(sample_size))

    ci= (sample_mean - margin_of_error, sample_mean + margin_of_error)
    print(f"{int(confidence_level * 100)}% CI: ({ci[0]:.2f}, {ci[1]:.2f})")
    print(f"Interpretation: We are {int(confidence_level * 100)}% confident that the true mean is between {ci[0]:.2f} and {ci[1]:.2f}.")

data = [85, 88, 92, 91, 87, 90, 85, 86, 89, 91]
population_std = 3
confidence_interval(sample_data, population_std)
# Out:
# 95% CI: (86.54, 90.26)
# Interpretation: We are 95% confident that the true mean is between 86.54 and 90.26.

# %% [markdown]
# 21. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
from scipy. stats import norm

def confidence_interval(data, std_dev, confidence_level=0.95):
    sample_mean = np.mean(data)
    sample_size = len(data)
    z_critical = norm.ppf(1 - (1 - confidence_level) / 2)
    margin_of_error = z_critical * (std_dev / np.sqrt(sample_size))

    ci= (sample_mean - margin_of_error, sample_mean + margin_of_error)
    print(f"{int(confidence_level * 100)}% CI: ({ci[0]:.2f}, {ci[1]:.2f})")
    print(f"Interpretation: We are {int(confidence_level * 100)}% confident that the true mean is between {ci[0]:.2f} and {ci[1]:.2f}.")

np.random.seed(0)
sample_data = np.random.normal(loc=100, scale=15, size=50)

population_std = 15
confidence_interval(sample_data, population_std)
# Out:
# 95% CI: (97.95, 106.27)
# Interpretation: We are 95% confident that the true mean is between 97.95 and 106.27.

# %% [markdown]
# 22. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy. stats import norm

mean = 0
std_dev = 1
x = np.linspace(-5, 5, 100)
pdf_values = norm.pdf(x, mean, std_dev)
plt.plot(x, pdf_values, label= f'Normal Distribution (μ={mean}, σ={std_dev})')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title('Probability Density Function (PDF) of a Normal Distribution')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 23. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy. stats import poisson

lambda_param = 5
k_values = np.arange(0, 15)
cdf_values = poisson.cdf(k_values, lambda_param)
plt.plot(k_values, cdf_values, marker= 'o', linestyle='-', color='blue', label=f'Poisson CDF (λ={lambda_param})')

plt.title('Cumulative Distribution Function (CDF) of a Poisson Distribution')
plt.xlabel('k')
plt.ylabel('Probability')
plt.grid(True)
plt.legend()
plt.show()

print(f"CDF values for Poisson Distribution (λ={lambda_param}):")
for k, cdf in zip(k_values, cdf_values):
    print(f"p(X <= {k}) = {cdf:.4f}")
# Out:
# CDF values for Poisson Distribution (λ=5):
# p(X <= 0) = 0.0067
# p(X <= 1) = 0.0404
# p(X <= 2) = 0.1247
# p(X <= 3) = 0.2650
# p(X <= 4) = 0.4405
# p(X <= 5) = 0.6160
# p(X <= 6) = 0.7622
# p(X <= 7) = 0.8666
# p(X <= 8) = 0.9319
# p(X <= 9) = 0.9682
# p(X <= 10) = 0.9863
# p(X <= 11) = 0.9945
# p(X <= 12) = 0.9980
# p(X <= 13) = 0.9993
# p(X <= 14) = 0.9998

# %% [markdown]
# 24. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
import numpy as np

a = 2
b = 8

sample_size = 1000
random_variable = np.random.uniform(a, b, sample_size)

expected_value =  (a + b) / 2
empirical_expected_value = np.mean(random_variable)

print(f"Theoretical expected value: {expected_value}")
print(f"Empirical expected value: {empirical_expected_value}")
# Out:
# Theoretical expected value: 5.0
# Empirical expected value: 5.060117227555223

# %% [markdown]
# 25. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

data1 = np.random.normal(loc=10, scale=5, size=1000)
data2 = np.random.normal(loc=10, scale=3, size=1000)

std_dev_1 = np.std(data1)
std_dev_2 = np.std(data2)

print(f"Standard Deviation of Dataset 1: {std_dev_1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev_2:.2f}")

labels = ['Dataset 1', 'Dataset 2']
std_devs = [std_dev_1, std_dev_2]

plt.bar(labels, std_devs, color=['blue', 'green'])
plt.title('Comparison of Standard Deviations')
plt.xlabel('Dataset')
plt.ylabel('Standard Deviation')
plt.show()
# Out:
# Standard Deviation of Dataset 1: 4.86
# Standard Deviation of Dataset 2: 2.97

# %% [markdown]
# 26. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np
np.random.seed(42)
data = np.random.normal(loc =50, scale=10, size=1000)

data_range = np.max(data) - np.min(data)

q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

print(f"Range of the dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range of the dataset: 70.94
# Interquartile Range (IQR): 12.96

# %% [markdown]
# 27. Implement Z-score normalization on a dataset and visualize its transformation

# %%
import numpy as np
import matplotlib.pyplot as plt

data =  np.random.normal(50, 10, 1000)
normalized_data = (data - np.mean(data)) / np.std(data)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
ax1.hist(data, bins=30, color='blue', alpha=0.7)
ax1.set_title('Original Data')
ax2.hist(normalized_data, bins=30, color='red', alpha=0.7)
ax2.set_title('Normalized Data')
plt.tight_layout()
plt.show()

# %% [markdown]
# 28. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(data):
    skewness = skew(data)
    kurt = kurtosis(data)
    return skewness, kurt

np.random.seed(42)
data = np.random.normal(loc=0, scale=1, size=1000)

skewness, kurt = calculate_skewness_kurtosis(data)
print(f"Skewness: {skewness:.4f}")
print(f"Kurtosis: {kurt:.4f}")
# Out:
# Skewness: 0.1168
# Kurtosis: 0.0662
